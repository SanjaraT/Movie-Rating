# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjaraT/Movie-Rating/blob/main/MovieRate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/movies.csv')
# Out:
# <ipython-input-43-942ebaf10c03>:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/drive/MyDrive/movies.csv')

# %%
data.head()
# Out:
#           id                          name               year  rating  \
# 0  tt4710316  Best in Sex: 2015 AVN Awards  (2015 TV Special)     4.0
# 1  tt1281857              Naughty Novelist       (2008 Video)     3.8
# 2  tt2294954          2011 AVN Awards Show  (2011 TV Special)     5.7
# 3  tt6843596  Best in Sex: 2017 AVN Awards  (2017 TV Special)     4.9
# 4  tt3705604               AVN Awards 2014  (2014 TV Special)     6.7
#
#      certificate duration        genre  votes gross_income  \
# 0          TV-MA   94 min  Adult, News  124.0            0
# 1  Not Certified   88 min        Adult  174.0            0
# 2  Not Certified   83 min  Adult, News   39.0            0
# 3          TV-MA   87 min  Adult, News  225.0            0
# 4              R   82 min  Adult, News  101.0            0
#
#           directors_id               directors_name  \
# 0            nm1624094                  Gary Miller
# 1            nm0045256                 John Bacchus
# ...

# %% [markdown]
# #Handling Missing Values

# %%
# Calculate and display the amount of missing values in each column
missing_values_per_column = data.isnull().sum()

print("Amount of Missing Values in Each Column:\n")
print(missing_values_per_column)
# Out:
# Amount of Missing Values in Each Column:
#
# id                0
# name              4
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# #Dropping missing values of name column

# %%
data.dropna(subset=['name'], inplace=True)

missing_values_per_column = df.isnull().sum()

print("Amount of Missing Values in Each Column:\n")
print(missing_values_per_column)
# Out:
# Amount of Missing Values in Each Column:
#
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# #Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.describe()
# Out:
#              rating
# count  2.590928e+06
# mean   1.000326e+01
# std    1.885601e+00
# min    1.000000e+00
# 25%    1.100000e+01
# 50%    1.100000e+01
# 75%    1.100000e+01
# max    1.100000e+01
